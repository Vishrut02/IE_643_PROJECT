# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np 
import pandas as pd
import xml.etree.ElementTree as ET
from PIL import Image
import cv2
import os
import xml.dom.minidom

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input, Concatenate, UpSampling2D
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
height , width = 1024 , 1024 #size to which input image needs to resize

def mapping(file_path):

  table_path = tf.strings.regex_replace(file_path, 'marmots_usuals', 'marmot_table')
  column_path = tf.strings.regex_replace(file_path, 'marmots_usuals', 'marmot_column')

  table_path = tf.strings.regex_replace(table_path, '.jpeg', '.bmp_table.jpeg')
  column_path = tf.strings.regex_replace(column_path, '.jpeg', '.bmp_col.jpeg')
  

  #reading  , resizing and normalizing for image data
  images = tf.io.read_file(file_path)
  images = tf.image.decode_jpeg(images, channels=3) #Decode a JPEG-encoded image to a uint8 tensor
  images = tf.cast(images, tf.float32) / 255.0 # normalizing image

  #reading  , resizing and normalizing for table mask data
  table_mask = tf.io.read_file(table_path)
  table_mask = tf.image.decode_jpeg(table_mask, channels=1) 
  table_mask = tf.image.resize(table_mask, [height, width]) #resizing image to input shape of model
  table_mask = tf.cast(table_mask, tf.float32) / 255.0 

  #reading  , resizing and normalizing for column mask data
  column_mask = tf.io.read_file(column_path)
  column_mask = tf.image.decode_jpeg(column_mask, channels=1) 
  column_mask = tf.image.resize(column_mask, [height, width]) 
  column_mask = tf.cast(column_mask, tf.float32) / 255.0 

  return images, {"table_mask" : table_mask, "column_mask" : column_mask }

def data_pipeline(dataset, input, batch_size=1):
    # Set AUTOTUNE for efficient data loading
    autotune = tf.data.experimental.AUTOTUNE

    # Calculate the total size of the dataset
    total_size = len(list(dataset))
    proportion = 0.9  # Proportion of data for training
    input_data_size = int(proportion * total_size)

    if input == 'train':
        # Take the training portion of the dataset
        input_data = dataset.take(input_data_size)
        
        # Map the dataset using the provided mapping function
        input_data = input_data.map(mapping, num_parallel_calls=autotune)
        train_data = input_data

        # Cache the data to improve performance during multiple epochs
        input_data = input_data.cache()

        # Shuffle the data to ensure randomness
        buffer_size = input_data_size
        input_data = input_data.shuffle(buffer_size)

        # Batch the data
        input_data = input_data.batch(batch_size)

        # Repeat the dataset indefinitely for training
        input_data = input_data.repeat()

        # Prefetch to improve performance
        input_data = input_data.prefetch(buffer_size=autotune)

        return input_data, train_data

    else:
        # Take the testing portion of the dataset by skipping the training portion
        input_data = dataset.skip(input_data_size)

        # Map the dataset using the provided mapping function
        input_data = input_data.map(mapping, num_parallel_calls=autotune)
        test_data = input_data

        # Cache the data to improve performance
        input_data = input_data.cache()

        # Shuffle the test data with a buffer size
        buffer_size = total_size - input_data_size
        input_data = input_data.shuffle(buffer_size)

        # Batch the data
        input_data = input_data.batch(batch_size)

        # Repeat the dataset to prevent running out of data during validation
        input_data = input_data.repeat()

        # Prefetch to improve data loading performance
        input_data = input_data.prefetch(buffer_size=autotune)

        return input_data, test_data

# %%
dataset = tf.data.Dataset.list_files("/kaggle/input/table-detection/marmots_usuals/marmots_usuals/*.jpeg")

# %%
train_dataloader , train_data = data_pipeline(dataset, 'train' , batch_size = 1)
test_dataloader , test_data= data_pipeline(dataset, 'test' , batch_size = 1)

number = 2
for image, mask  in test_data.take(number):
  plt.figure(figsize=(15, 15))
  lists = [image, mask['table_mask'], mask['column_mask']]
  title = ['Image', 'Table Mask', 'Column Mask']         
  for i in range(len(lists)):
    plt.subplot(1, len(lists), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(lists[i]))
    plt.axis('off')
  plt.show()   


inputShape = (1024, 1024, 3)
inputs = Input(shape=inputShape, name='input')

# %%
vgg_19=tf.keras.applications.VGG19(input_tensor=inputs,include_top=False, weights='imagenet', pooling=None, classes=1000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#addding 2 (1 * 1) convolutional layers followed by dropot eith 80%
x = Conv2D(512, (1, 1), activation = 'relu', name='block6_conv1')(vgg_19.output)
x = Dropout(0.8, name='block6_dropout1')(x)
x = Conv2D(512, (1, 1), activation = 'relu', name='block6_conv2')(x)
x = Dropout(0.8, name = 'block6_dropout2')(x)


#taking 3rd and 4th maxpool layer from vgg_19 for decoders
block3_pool=vgg_19.get_layer('block3_pool').output
block4_pool=vgg_19.get_layer('block4_pool').output

# %%
import os
import tensorflow as tf
from keras.layers import Conv2D, Dropout, UpSampling2D, Concatenate
from keras.models import Model
from keras.saving import register_keras_serializable

# Register the custom layer with Keras
@register_keras_serializable(package="Custom", name="table_decoder")
class table_decoder(tf.keras.layers.Layer):
    def __init__(self, name="table_mask", trainable=True, dtype=None, **kwargs):
        # Accept and pass trainable, dtype, and other keyword arguments to the base Layer
        super().__init__(name=name, trainable=trainable, dtype=dtype, **kwargs)
        self.conv1 = Conv2D(filters=512, kernel_size=(1, 1), activation='relu')
        self.upsample1 = UpSampling2D(size=(2, 2))
        self.upsample2 = UpSampling2D(size=(2, 2))
        self.upsample3 = UpSampling2D(size=(2, 2))
        self.upsample4 = UpSampling2D(size=(2, 2))
        self.convtraspose = tf.keras.layers.Conv2DTranspose(3, 3, strides=2, padding='same')

    def call(self, X):
        input, pool_3, pool_4 = X[0], X[1], X[2]
        result = self.conv1(input)
        result = self.upsample1(result)
        result = Concatenate()([result, pool_4])
        result = self.upsample2(result)
        result = Concatenate()([result, pool_3])
        result = self.upsample3(result)
        result = self.upsample4(result)
        result = self.convtraspose(result)
        return result

# Register the custom layer with Keras
@register_keras_serializable(package="Custom", name="column_decoder")
class column_decoder(tf.keras.layers.Layer):
    def __init__(self, name="column_mask", trainable=True, dtype=None, **kwargs):
        # Accept and pass trainable, dtype, and other keyword arguments to the base Layer
        super().__init__(name=name, trainable=trainable, dtype=dtype, **kwargs)
        self.conv1 = Conv2D(filters=512, kernel_size=(1, 1), activation='relu')
        self.drop = Dropout(0.8)
        self.conv2 = Conv2D(filters=512, kernel_size=(1, 1), activation='relu')
        self.upsample1 = UpSampling2D(size=(2, 2))
        self.upsample2 = UpSampling2D(size=(2, 2))
        self.upsample3 = UpSampling2D(size=(2, 2))
        self.upsample4 = UpSampling2D(size=(2, 2))
        self.convtraspose = tf.keras.layers.Conv2DTranspose(3, 3, strides=2, padding='same', name='column_mask')

    def call(self, X):
        input, pool_3, pool_4 = X[0], X[1], X[2]
        result = self.conv1(input)
        result = self.drop(result)
        result = self.conv2(result)
        result = self.upsample1(result)
        result = Concatenate()([result, pool_4])
        result = self.upsample2(result)
        result = Concatenate()([result, pool_3])
        result = self.upsample3(result)
        result = self.upsample4(result)
        result = self.convtraspose(result)
        return result

# Define the inputs and encoder results
encoder_result = [x, block3_pool, block4_pool]

# Initialize the custom decoders
Table_Decoder = table_decoder()
Column_Decoder = column_decoder()

# Get outputs from the decoders
output1 = Table_Decoder(encoder_result)
output2 = Column_Decoder(encoder_result)

# Create the model
model = Model(inputs=inputs, outputs=[output1, output2], name="tablenet")

# Visualize the model
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)
model.summary()

# Define the loss functions
losses = {
    "table_mask": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    "column_mask": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
}

# Define loss weights
lossWeights = {"table_mask": 1.0, "column_mask": 1.0}

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, epsilon=1e-08),
              loss=losses,
              metrics=['accuracy', 'accuracy'],
              loss_weights=lossWeights)

# Create the checkpoint directory
checkpoint_dir = '/kaggle/working/checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)
print(f"Checkpoint directory created at: {checkpoint_dir}")

# Configure ModelCheckpoint to save the model in .keras format
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, 'mymodel_{epoch:02d}.keras'),
    monitor="val_loss",
    save_best_only=True,
    mode='min',
    verbose=1
)
# Out:
# Model: "tablenet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 1024,      │          0 │ -                 │
# │                     │ 1024, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 1024,      │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 1024, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 1024,      │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 1024, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 512, 512,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 512, 512,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 512, 512,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 256, 256,  │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 256, 256,  │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 256, 256,  │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 256, 256,  │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv4        │ (None, 256, 256,  │    590,080 │ block3_conv3[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 128, 128,  │          0 │ block3_conv4[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 128, 128,  │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 128, 128,  │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 128, 128,  │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv4        │ (None, 128, 128,  │  2,359,808 │ block4_conv3[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 64, 64,    │          0 │ block4_conv4[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 64, 64,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 64, 64,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 64, 64,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv4        │ (None, 64, 64,    │  2,359,808 │ block5_conv3[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 32, 32,    │          0 │ block5_conv4[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_conv1        │ (None, 32, 32,    │    262,656 │ block5_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_dropout1     │ (None, 32, 32,    │          0 │ block6_conv1[0][… │
# │ (Dropout)           │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_conv2        │ (None, 32, 32,    │    262,656 │ block6_dropout1[… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_dropout2     │ (None, 32, 32,    │          0 │ block6_conv2[0][… │
# │ (Dropout)           │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ table_mask          │ (None, 1024,      │    297,219 │ block6_dropout2[… │
# │ (table_decoder)     │ 1024, 3)          │            │ block3_pool[0][0… │
# │                     │                   │            │ block4_pool[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ column_mask         │ (None, 1024,      │    559,875 │ block6_dropout2[… │
# │ (column_decoder)    │ 1024, 3)          │            │ block3_pool[0][0… │
# │                     │                   │            │ block4_pool[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,406,790 (81.66 MB)
#  Trainable params: 21,406,790 (81.66 MB)
#  Non-trainable params: 0 (0.00 B)
# Checkpoint directory created at: /kaggle/working/checkpoints

# %%
from tensorflow.keras.models import load_model
batch_size = 1
steps_per_epoch = len(train_data) // batch_size
validation_steps = len(test_data) // batch_size
model_history=model.fit(
    train_dataloader,
    epochs=200,
    steps_per_epoch=steps_per_epoch,
    validation_data=test_dataloader,
    validation_steps=validation_steps,
    callbacks=[model_checkpoint]  # Make sure this is in a list
)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727769940.782768      64 service.cc:145] XLA service 0x7efc78001c20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727769940.782829      64 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# W0000 00:00:1727769941.432543      64 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# W0000 00:00:1727769941.442843      64 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy_1/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2024-10-01 08:05:52.723546: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[1,1280,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,1025,1025]{3,2,1,0}, f32[1280,3,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-10-01 08:05:52.877563: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.154228887s
# Trying algorithm eng4{} for conv (f32[1,1280,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,1025,1025]{3,2,1,0}, f32[1280,3,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727769964.337293      64 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_12', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_10', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_9', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_11', 4 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1727769964.353079      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.8644 - loss: 0.7583 - table_mask_accuracy: 0.8576
# W0000 00:00:1727770089.398094      67 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# W0000 00:00:1727770089.400254      67 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy_1/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# Epoch 1: val_loss improved from inf to 0.60213, saving model to /kaggle/working/checkpoints/mymodel_01.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 169s 295ms/step - column_mask_accuracy: 0.8644 - loss: 0.7579 - table_mask_accuracy: 0.8577 - val_column_mask_accuracy: 0.8768 - val_loss: 0.6021 - val_table_mask_accuracy: 0.8895
# Epoch 2/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9022 - loss: 0.3844 - table_mask_accuracy: 0.9128
# Epoch 2: val_loss did not improve from 0.60213
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9022 - loss: 0.3844 - table_mask_accuracy: 0.9128 - val_column_mask_accuracy: 0.8981 - val_loss: 0.6363 - val_table_mask_accuracy: 0.9264
# Epoch 3/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9082 - loss: 0.3441 - table_mask_accuracy: 0.9256
# Epoch 3: val_loss improved from 0.60213 to 0.46563, saving model to /kaggle/working/checkpoints/mymodel_03.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9082 - loss: 0.3441 - table_mask_accuracy: 0.9256 - val_column_mask_accuracy: 0.9052 - val_loss: 0.4656 - val_table_mask_accuracy: 0.9344
# Epoch 4/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9137 - loss: 0.2944 - table_mask_accuracy: 0.9358
# Epoch 4: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9137 - loss: 0.2944 - table_mask_accuracy: 0.9358 - val_column_mask_accuracy: 0.8664 - val_loss: 0.7215 - val_table_mask_accuracy: 0.9124
# Epoch 5/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9204 - loss: 0.2540 - table_mask_accuracy: 0.9461
# Epoch 5: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9204 - loss: 0.2540 - table_mask_accuracy: 0.9461 - val_column_mask_accuracy: 0.8974 - val_loss: 0.5945 - val_table_mask_accuracy: 0.9407
# Epoch 6/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9257 - loss: 0.2363 - table_mask_accuracy: 0.9513
# Epoch 6: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9257 - loss: 0.2363 - table_mask_accuracy: 0.9513 - val_column_mask_accuracy: 0.9004 - val_loss: 0.4808 - val_table_mask_accuracy: 0.9415
# Epoch 7/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9240 - loss: 0.2394 - table_mask_accuracy: 0.9499
# Epoch 7: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9240 - loss: 0.2393 - table_mask_accuracy: 0.9499 - val_column_mask_accuracy: 0.8518 - val_loss: 0.7174 - val_table_mask_accuracy: 0.9064
# Epoch 8/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9254 - loss: 0.2178 - table_mask_accuracy: 0.9545
# Epoch 8: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9254 - loss: 0.2178 - table_mask_accuracy: 0.9545 - val_column_mask_accuracy: 0.8574 - val_loss: 0.7172 - val_table_mask_accuracy: 0.9101
# Epoch 9/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9341 - loss: 0.2102 - table_mask_accuracy: 0.9553
# Epoch 9: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9341 - loss: 0.2102 - table_mask_accuracy: 0.9553 - val_column_mask_accuracy: 0.8683 - val_loss: 0.6287 - val_table_mask_accuracy: 0.9402
# Epoch 10/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9328 - loss: 0.1938 - table_mask_accuracy: 0.9592
# Epoch 10: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9328 - loss: 0.1938 - table_mask_accuracy: 0.9592 - val_column_mask_accuracy: 0.8977 - val_loss: 0.5233 - val_table_mask_accuracy: 0.9590
# Epoch 11/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9339 - loss: 0.1908 - table_mask_accuracy: 0.9586
# Epoch 11: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9339 - loss: 0.1909 - table_mask_accuracy: 0.9586 - val_column_mask_accuracy: 0.8793 - val_loss: 0.5653 - val_table_mask_accuracy: 0.9427
# Epoch 12/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9329 - loss: 0.1862 - table_mask_accuracy: 0.9606
# Epoch 12: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9329 - loss: 0.1862 - table_mask_accuracy: 0.9606 - val_column_mask_accuracy: 0.8228 - val_loss: 0.6557 - val_table_mask_accuracy: 0.9249
# Epoch 13/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9376 - loss: 0.1640 - table_mask_accuracy: 0.9651
# Epoch 13: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9375 - loss: 0.1641 - table_mask_accuracy: 0.9651 - val_column_mask_accuracy: 0.8588 - val_loss: 0.6246 - val_table_mask_accuracy: 0.9325
# Epoch 14/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9311 - loss: 0.1830 - table_mask_accuracy: 0.9609
# Epoch 14: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9311 - loss: 0.1830 - table_mask_accuracy: 0.9609 - val_column_mask_accuracy: 0.8337 - val_loss: 0.6763 - val_table_mask_accuracy: 0.9180
# Epoch 15/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9357 - loss: 0.1651 - table_mask_accuracy: 0.9654
# Epoch 15: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9357 - loss: 0.1651 - table_mask_accuracy: 0.9654 - val_column_mask_accuracy: 0.8466 - val_loss: 0.6178 - val_table_mask_accuracy: 0.9380
# Epoch 16/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9275 - loss: 0.2187 - table_mask_accuracy: 0.9569
# Epoch 16: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9275 - loss: 0.2186 - table_mask_accuracy: 0.9569 - val_column_mask_accuracy: 0.8423 - val_loss: 0.5897 - val_table_mask_accuracy: 0.9471
# Epoch 17/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9357 - loss: 0.1544 - table_mask_accuracy: 0.9674
# Epoch 17: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9357 - loss: 0.1544 - table_mask_accuracy: 0.9674 - val_column_mask_accuracy: 0.8544 - val_loss: 0.6212 - val_table_mask_accuracy: 0.9217
# Epoch 18/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9357 - loss: 0.1639 - table_mask_accuracy: 0.9643
# Epoch 18: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9357 - loss: 0.1639 - table_mask_accuracy: 0.9643 - val_column_mask_accuracy: 0.7966 - val_loss: 0.6418 - val_table_mask_accuracy: 0.9267
# Epoch 19/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9369 - loss: 0.1588 - table_mask_accuracy: 0.9664
# Epoch 19: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9369 - loss: 0.1588 - table_mask_accuracy: 0.9663 - val_column_mask_accuracy: 0.7710 - val_loss: 0.8472 - val_table_mask_accuracy: 0.8587
# Epoch 20/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9357 - loss: 0.1751 - table_mask_accuracy: 0.9630
# Epoch 20: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9357 - loss: 0.1750 - table_mask_accuracy: 0.9631 - val_column_mask_accuracy: 0.7697 - val_loss: 0.7616 - val_table_mask_accuracy: 0.9005
# Epoch 21/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9406 - loss: 0.1377 - table_mask_accuracy: 0.9699
# Epoch 21: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9406 - loss: 0.1377 - table_mask_accuracy: 0.9699 - val_column_mask_accuracy: 0.7751 - val_loss: 0.7003 - val_table_mask_accuracy: 0.9060
# Epoch 22/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9381 - loss: 0.1492 - table_mask_accuracy: 0.9679
# Epoch 22: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9381 - loss: 0.1492 - table_mask_accuracy: 0.9679 - val_column_mask_accuracy: 0.6744 - val_loss: 0.9597 - val_table_mask_accuracy: 0.8308
# Epoch 23/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9419 - loss: 0.1302 - table_mask_accuracy: 0.9707
# Epoch 23: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9419 - loss: 0.1302 - table_mask_accuracy: 0.9707 - val_column_mask_accuracy: 0.7377 - val_loss: 0.7155 - val_table_mask_accuracy: 0.9135
# Epoch 24/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9436 - loss: 0.1227 - table_mask_accuracy: 0.9719
# Epoch 24: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9436 - loss: 0.1227 - table_mask_accuracy: 0.9719 - val_column_mask_accuracy: 0.6746 - val_loss: 1.0861 - val_table_mask_accuracy: 0.7256
# Epoch 25/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9450 - loss: 0.1138 - table_mask_accuracy: 0.9741
# Epoch 25: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9450 - loss: 0.1138 - table_mask_accuracy: 0.9741 - val_column_mask_accuracy: 0.7803 - val_loss: 0.6683 - val_table_mask_accuracy: 0.9110
# Epoch 26/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9369 - loss: 0.1603 - table_mask_accuracy: 0.9646
# Epoch 26: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9369 - loss: 0.1604 - table_mask_accuracy: 0.9646 - val_column_mask_accuracy: 0.8879 - val_loss: 0.5973 - val_table_mask_accuracy: 0.9251
# Epoch 27/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9366 - loss: 0.1435 - table_mask_accuracy: 0.9681
# Epoch 27: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9366 - loss: 0.1435 - table_mask_accuracy: 0.9681 - val_column_mask_accuracy: 0.8817 - val_loss: 0.5886 - val_table_mask_accuracy: 0.9338
# Epoch 28/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9435 - loss: 0.1245 - table_mask_accuracy: 0.9722
# Epoch 28: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9435 - loss: 0.1245 - table_mask_accuracy: 0.9722 - val_column_mask_accuracy: 0.7962 - val_loss: 0.7086 - val_table_mask_accuracy: 0.8779
# Epoch 29/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9431 - loss: 0.1116 - table_mask_accuracy: 0.9741
# Epoch 29: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9431 - loss: 0.1116 - table_mask_accuracy: 0.9741 - val_column_mask_accuracy: 0.7664 - val_loss: 0.6943 - val_table_mask_accuracy: 0.8939
# Epoch 30/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9440 - loss: 0.1110 - table_mask_accuracy: 0.9745
# Epoch 30: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9440 - loss: 0.1110 - table_mask_accuracy: 0.9745 - val_column_mask_accuracy: 0.8356 - val_loss: 0.5677 - val_table_mask_accuracy: 0.9066
# Epoch 31/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9454 - loss: 0.1051 - table_mask_accuracy: 0.9746
# Epoch 31: val_loss did not improve from 0.46563
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9454 - loss: 0.1051 - table_mask_accuracy: 0.9746 - val_column_mask_accuracy: 0.8590 - val_loss: 0.5550 - val_table_mask_accuracy: 0.9065
# Epoch 32/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9457 - loss: 0.1016 - table_mask_accuracy: 0.9762
# Epoch 32: val_loss improved from 0.46563 to 0.45767, saving model to /kaggle/working/checkpoints/mymodel_32.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9457 - loss: 0.1016 - table_mask_accuracy: 0.9762 - val_column_mask_accuracy: 0.8961 - val_loss: 0.4577 - val_table_mask_accuracy: 0.9360
# Epoch 33/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9335 - loss: 0.2105 - table_mask_accuracy: 0.9607
# Epoch 33: val_loss did not improve from 0.45767
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9336 - loss: 0.2104 - table_mask_accuracy: 0.9607 - val_column_mask_accuracy: 0.8747 - val_loss: 0.5236 - val_table_mask_accuracy: 0.9337
# Epoch 34/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9446 - loss: 0.1073 - table_mask_accuracy: 0.9750
# Epoch 34: val_loss did not improve from 0.45767
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9446 - loss: 0.1073 - table_mask_accuracy: 0.9750 - val_column_mask_accuracy: 0.8391 - val_loss: 0.5299 - val_table_mask_accuracy: 0.9320
# Epoch 35/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9494 - loss: 0.0915 - table_mask_accuracy: 0.9776
# Epoch 35: val_loss improved from 0.45767 to 0.40345, saving model to /kaggle/working/checkpoints/mymodel_35.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9494 - loss: 0.0915 - table_mask_accuracy: 0.9776 - val_column_mask_accuracy: 0.8992 - val_loss: 0.4034 - val_table_mask_accuracy: 0.9390
# Epoch 36/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9457 - loss: 0.0943 - table_mask_accuracy: 0.9770
# Epoch 36: val_loss improved from 0.40345 to 0.33855, saving model to /kaggle/working/checkpoints/mymodel_36.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9457 - loss: 0.0943 - table_mask_accuracy: 0.9770 - val_column_mask_accuracy: 0.9019 - val_loss: 0.3386 - val_table_mask_accuracy: 0.9570
# Epoch 37/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9483 - loss: 0.0910 - table_mask_accuracy: 0.9773
# Epoch 37: val_loss improved from 0.33855 to 0.24463, saving model to /kaggle/working/checkpoints/mymodel_37.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9483 - loss: 0.0910 - table_mask_accuracy: 0.9773 - val_column_mask_accuracy: 0.9331 - val_loss: 0.2446 - val_table_mask_accuracy: 0.9635
# Epoch 38/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9477 - loss: 0.0987 - table_mask_accuracy: 0.9757
# Epoch 38: val_loss did not improve from 0.24463
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9477 - loss: 0.0987 - table_mask_accuracy: 0.9757 - val_column_mask_accuracy: 0.8703 - val_loss: 0.4669 - val_table_mask_accuracy: 0.9073
# Epoch 39/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9456 - loss: 0.1155 - table_mask_accuracy: 0.9733
# Epoch 39: val_loss did not improve from 0.24463
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9456 - loss: 0.1154 - table_mask_accuracy: 0.9733 - val_column_mask_accuracy: 0.9075 - val_loss: 0.3907 - val_table_mask_accuracy: 0.9194
# Epoch 40/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9461 - loss: 0.0934 - table_mask_accuracy: 0.9774
# Epoch 40: val_loss did not improve from 0.24463
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9461 - loss: 0.0934 - table_mask_accuracy: 0.9774 - val_column_mask_accuracy: 0.8606 - val_loss: 0.6131 - val_table_mask_accuracy: 0.8995
# Epoch 41/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9384 - loss: 0.1773 - table_mask_accuracy: 0.9634
# Epoch 41: val_loss did not improve from 0.24463
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 287ms/step - column_mask_accuracy: 0.9384 - loss: 0.1772 - table_mask_accuracy: 0.9634 - val_column_mask_accuracy: 0.8996 - val_loss: 0.3582 - val_table_mask_accuracy: 0.9585
# Epoch 42/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9467 - loss: 0.0972 - table_mask_accuracy: 0.9763
# Epoch 42: val_loss did not improve from 0.24463
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9467 - loss: 0.0972 - table_mask_accuracy: 0.9763 - val_column_mask_accuracy: 0.8880 - val_loss: 0.3594 - val_table_mask_accuracy: 0.9583
# Epoch 43/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9468 - loss: 0.0878 - table_mask_accuracy: 0.9780
# Epoch 43: val_loss improved from 0.24463 to 0.23434, saving model to /kaggle/working/checkpoints/mymodel_43.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9468 - loss: 0.0878 - table_mask_accuracy: 0.9780 - val_column_mask_accuracy: 0.9330 - val_loss: 0.2343 - val_table_mask_accuracy: 0.9650
# Epoch 44/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9476 - loss: 0.0849 - table_mask_accuracy: 0.9786
# Epoch 44: val_loss improved from 0.23434 to 0.22818, saving model to /kaggle/working/checkpoints/mymodel_44.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9476 - loss: 0.0849 - table_mask_accuracy: 0.9786 - val_column_mask_accuracy: 0.9300 - val_loss: 0.2282 - val_table_mask_accuracy: 0.9634
# Epoch 45/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9506 - loss: 0.0770 - table_mask_accuracy: 0.9796
# Epoch 45: val_loss did not improve from 0.22818
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9506 - loss: 0.0770 - table_mask_accuracy: 0.9796 - val_column_mask_accuracy: 0.9014 - val_loss: 0.3366 - val_table_mask_accuracy: 0.9397
# Epoch 46/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9487 - loss: 0.0814 - table_mask_accuracy: 0.9787
# Epoch 46: val_loss did not improve from 0.22818
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9487 - loss: 0.0814 - table_mask_accuracy: 0.9787 - val_column_mask_accuracy: 0.9226 - val_loss: 0.2856 - val_table_mask_accuracy: 0.9596
# Epoch 47/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9455 - loss: 0.0923 - table_mask_accuracy: 0.9766
# Epoch 47: val_loss did not improve from 0.22818
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9455 - loss: 0.0923 - table_mask_accuracy: 0.9766 - val_column_mask_accuracy: 0.9200 - val_loss: 0.3557 - val_table_mask_accuracy: 0.9319
# Epoch 48/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9491 - loss: 0.0882 - table_mask_accuracy: 0.9775
# Epoch 48: val_loss did not improve from 0.22818
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9491 - loss: 0.0882 - table_mask_accuracy: 0.9775 - val_column_mask_accuracy: 0.9138 - val_loss: 0.3220 - val_table_mask_accuracy: 0.9410
# Epoch 49/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9493 - loss: 0.0790 - table_mask_accuracy: 0.9792
# Epoch 49: val_loss improved from 0.22818 to 0.20485, saving model to /kaggle/working/checkpoints/mymodel_49.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9493 - loss: 0.0790 - table_mask_accuracy: 0.9792 - val_column_mask_accuracy: 0.9452 - val_loss: 0.2048 - val_table_mask_accuracy: 0.9607
# Epoch 50/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9494 - loss: 0.0753 - table_mask_accuracy: 0.9794
# Epoch 50: val_loss improved from 0.20485 to 0.17207, saving model to /kaggle/working/checkpoints/mymodel_50.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9494 - loss: 0.0753 - table_mask_accuracy: 0.9794 - val_column_mask_accuracy: 0.9408 - val_loss: 0.1721 - val_table_mask_accuracy: 0.9689
# Epoch 51/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9536 - loss: 0.0712 - table_mask_accuracy: 0.9804
# Epoch 51: val_loss improved from 0.17207 to 0.15757, saving model to /kaggle/working/checkpoints/mymodel_51.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9536 - loss: 0.0712 - table_mask_accuracy: 0.9804 - val_column_mask_accuracy: 0.9437 - val_loss: 0.1576 - val_table_mask_accuracy: 0.9708
# Epoch 52/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9508 - loss: 0.0755 - table_mask_accuracy: 0.9797
# Epoch 52: val_loss did not improve from 0.15757
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9508 - loss: 0.0755 - table_mask_accuracy: 0.9797 - val_column_mask_accuracy: 0.9406 - val_loss: 0.1796 - val_table_mask_accuracy: 0.9660
# Epoch 53/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9515 - loss: 0.0696 - table_mask_accuracy: 0.9805
# Epoch 53: val_loss improved from 0.15757 to 0.14294, saving model to /kaggle/working/checkpoints/mymodel_53.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9515 - loss: 0.0696 - table_mask_accuracy: 0.9805 - val_column_mask_accuracy: 0.9452 - val_loss: 0.1429 - val_table_mask_accuracy: 0.9716
# Epoch 54/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9414 - loss: 0.1279 - table_mask_accuracy: 0.9692
# Epoch 54: val_loss did not improve from 0.14294
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9414 - loss: 0.1280 - table_mask_accuracy: 0.9691 - val_column_mask_accuracy: 0.9240 - val_loss: 0.2885 - val_table_mask_accuracy: 0.9532
# Epoch 55/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9406 - loss: 0.1390 - table_mask_accuracy: 0.9690
# Epoch 55: val_loss did not improve from 0.14294
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 287ms/step - column_mask_accuracy: 0.9406 - loss: 0.1390 - table_mask_accuracy: 0.9690 - val_column_mask_accuracy: 0.9437 - val_loss: 0.2107 - val_table_mask_accuracy: 0.9712
# Epoch 56/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9495 - loss: 0.0893 - table_mask_accuracy: 0.9771
# Epoch 56: val_loss did not improve from 0.14294
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9495 - loss: 0.0893 - table_mask_accuracy: 0.9771 - val_column_mask_accuracy: 0.9426 - val_loss: 0.1765 - val_table_mask_accuracy: 0.9681
# Epoch 57/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9554 - loss: 0.0693 - table_mask_accuracy: 0.9810
# Epoch 57: val_loss improved from 0.14294 to 0.12990, saving model to /kaggle/working/checkpoints/mymodel_57.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 289ms/step - column_mask_accuracy: 0.9554 - loss: 0.0693 - table_mask_accuracy: 0.9810 - val_column_mask_accuracy: 0.9469 - val_loss: 0.1299 - val_table_mask_accuracy: 0.9724
# Epoch 58/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9517 - loss: 0.0672 - table_mask_accuracy: 0.9806
# Epoch 58: val_loss did not improve from 0.12990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9517 - loss: 0.0672 - table_mask_accuracy: 0.9806 - val_column_mask_accuracy: 0.9460 - val_loss: 0.1335 - val_table_mask_accuracy: 0.9691
# Epoch 59/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9546 - loss: 0.0636 - table_mask_accuracy: 0.9814
# Epoch 59: val_loss improved from 0.12990 to 0.10956, saving model to /kaggle/working/checkpoints/mymodel_59.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 289ms/step - column_mask_accuracy: 0.9546 - loss: 0.0636 - table_mask_accuracy: 0.9814 - val_column_mask_accuracy: 0.9517 - val_loss: 0.1096 - val_table_mask_accuracy: 0.9742
# Epoch 60/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9536 - loss: 0.0641 - table_mask_accuracy: 0.9808
# Epoch 60: val_loss did not improve from 0.10956
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9536 - loss: 0.0641 - table_mask_accuracy: 0.9808 - val_column_mask_accuracy: 0.9497 - val_loss: 0.1182 - val_table_mask_accuracy: 0.9736
# Epoch 61/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9536 - loss: 0.0615 - table_mask_accuracy: 0.9813
# Epoch 61: val_loss did not improve from 0.10956
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9536 - loss: 0.0615 - table_mask_accuracy: 0.9813 - val_column_mask_accuracy: 0.9512 - val_loss: 0.1151 - val_table_mask_accuracy: 0.9741
# Epoch 62/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9547 - loss: 0.0617 - table_mask_accuracy: 0.9811
# Epoch 62: val_loss did not improve from 0.10956
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9547 - loss: 0.0617 - table_mask_accuracy: 0.9811 - val_column_mask_accuracy: 0.9495 - val_loss: 0.2036 - val_table_mask_accuracy: 0.9413
# Epoch 63/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9533 - loss: 0.0641 - table_mask_accuracy: 0.9810
# Epoch 63: val_loss did not improve from 0.10956
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9533 - loss: 0.0641 - table_mask_accuracy: 0.9810 - val_column_mask_accuracy: 0.9490 - val_loss: 0.1287 - val_table_mask_accuracy: 0.9697
# Epoch 64/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9576 - loss: 0.0577 - table_mask_accuracy: 0.9820
# Epoch 64: val_loss did not improve from 0.10956
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9576 - loss: 0.0577 - table_mask_accuracy: 0.9820 - val_column_mask_accuracy: 0.9493 - val_loss: 0.1511 - val_table_mask_accuracy: 0.9704
# Epoch 65/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9520 - loss: 0.0737 - table_mask_accuracy: 0.9794
# Epoch 65: val_loss did not improve from 0.10956
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9520 - loss: 0.0738 - table_mask_accuracy: 0.9794 - val_column_mask_accuracy: 0.9180 - val_loss: 0.4356 - val_table_mask_accuracy: 0.9223
# Epoch 66/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9365 - loss: 0.1505 - table_mask_accuracy: 0.9659
# Epoch 66: val_loss improved from 0.10956 to 0.10740, saving model to /kaggle/working/checkpoints/mymodel_66.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9365 - loss: 0.1504 - table_mask_accuracy: 0.9660 - val_column_mask_accuracy: 0.9504 - val_loss: 0.1074 - val_table_mask_accuracy: 0.9774
# Epoch 67/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9509 - loss: 0.0733 - table_mask_accuracy: 0.9793
# Epoch 67: val_loss improved from 0.10740 to 0.08771, saving model to /kaggle/working/checkpoints/mymodel_67.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 289ms/step - column_mask_accuracy: 0.9509 - loss: 0.0733 - table_mask_accuracy: 0.9793 - val_column_mask_accuracy: 0.9541 - val_loss: 0.0877 - val_table_mask_accuracy: 0.9806
# Epoch 68/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9541 - loss: 0.0629 - table_mask_accuracy: 0.9808
# Epoch 68: val_loss improved from 0.08771 to 0.07876, saving model to /kaggle/working/checkpoints/mymodel_68.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9541 - loss: 0.0629 - table_mask_accuracy: 0.9808 - val_column_mask_accuracy: 0.9545 - val_loss: 0.0788 - val_table_mask_accuracy: 0.9811
# Epoch 69/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9505 - loss: 0.0611 - table_mask_accuracy: 0.9812
# Epoch 69: val_loss did not improve from 0.07876
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9505 - loss: 0.0611 - table_mask_accuracy: 0.9812 - val_column_mask_accuracy: 0.9546 - val_loss: 0.0817 - val_table_mask_accuracy: 0.9803
# Epoch 70/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9557 - loss: 0.0549 - table_mask_accuracy: 0.9816
# Epoch 70: val_loss improved from 0.07876 to 0.07602, saving model to /kaggle/working/checkpoints/mymodel_70.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9557 - loss: 0.0549 - table_mask_accuracy: 0.9816 - val_column_mask_accuracy: 0.9560 - val_loss: 0.0760 - val_table_mask_accuracy: 0.9811
# Epoch 71/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9568 - loss: 0.0543 - table_mask_accuracy: 0.9817
# Epoch 71: val_loss did not improve from 0.07602
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9568 - loss: 0.0543 - table_mask_accuracy: 0.9817 - val_column_mask_accuracy: 0.9545 - val_loss: 0.0807 - val_table_mask_accuracy: 0.9802
# Epoch 72/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9556 - loss: 0.0545 - table_mask_accuracy: 0.9817
# Epoch 72: val_loss did not improve from 0.07602
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9556 - loss: 0.0545 - table_mask_accuracy: 0.9817 - val_column_mask_accuracy: 0.9562 - val_loss: 0.0780 - val_table_mask_accuracy: 0.9806
# Epoch 73/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9556 - loss: 0.0559 - table_mask_accuracy: 0.9810
# Epoch 73: val_loss improved from 0.07602 to 0.07437, saving model to /kaggle/working/checkpoints/mymodel_73.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9556 - loss: 0.0559 - table_mask_accuracy: 0.9810 - val_column_mask_accuracy: 0.9556 - val_loss: 0.0744 - val_table_mask_accuracy: 0.9807
# Epoch 74/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9545 - loss: 0.0634 - table_mask_accuracy: 0.9805
# Epoch 74: val_loss did not improve from 0.07437
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9545 - loss: 0.0635 - table_mask_accuracy: 0.9805 - val_column_mask_accuracy: 0.9342 - val_loss: 0.3370 - val_table_mask_accuracy: 0.9486
# Epoch 75/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9446 - loss: 0.1179 - table_mask_accuracy: 0.9711
# Epoch 75: val_loss did not improve from 0.07437
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9446 - loss: 0.1179 - table_mask_accuracy: 0.9711 - val_column_mask_accuracy: 0.9534 - val_loss: 0.0819 - val_table_mask_accuracy: 0.9810
# Epoch 76/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9539 - loss: 0.0604 - table_mask_accuracy: 0.9815
# Epoch 76: val_loss did not improve from 0.07437
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9539 - loss: 0.0604 - table_mask_accuracy: 0.9815 - val_column_mask_accuracy: 0.9537 - val_loss: 0.0804 - val_table_mask_accuracy: 0.9803
# Epoch 77/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9537 - loss: 0.0552 - table_mask_accuracy: 0.9813
# Epoch 77: val_loss improved from 0.07437 to 0.06944, saving model to /kaggle/working/checkpoints/mymodel_77.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9537 - loss: 0.0552 - table_mask_accuracy: 0.9813 - val_column_mask_accuracy: 0.9560 - val_loss: 0.0694 - val_table_mask_accuracy: 0.9815
# Epoch 78/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9557 - loss: 0.0521 - table_mask_accuracy: 0.9816
# Epoch 78: val_loss did not improve from 0.06944
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9557 - loss: 0.0521 - table_mask_accuracy: 0.9816 - val_column_mask_accuracy: 0.9550 - val_loss: 0.0764 - val_table_mask_accuracy: 0.9812
# Epoch 79/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9566 - loss: 0.0523 - table_mask_accuracy: 0.9816
# Epoch 79: val_loss did not improve from 0.06944
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9566 - loss: 0.0523 - table_mask_accuracy: 0.9816 - val_column_mask_accuracy: 0.9566 - val_loss: 0.0796 - val_table_mask_accuracy: 0.9806
# Epoch 80/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9554 - loss: 0.0526 - table_mask_accuracy: 0.9813
# Epoch 80: val_loss improved from 0.06944 to 0.06923, saving model to /kaggle/working/checkpoints/mymodel_80.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9554 - loss: 0.0526 - table_mask_accuracy: 0.9813 - val_column_mask_accuracy: 0.9558 - val_loss: 0.0692 - val_table_mask_accuracy: 0.9815
# Epoch 81/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9559 - loss: 0.0522 - table_mask_accuracy: 0.9813
# Epoch 81: val_loss improved from 0.06923 to 0.06759, saving model to /kaggle/working/checkpoints/mymodel_81.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9559 - loss: 0.0522 - table_mask_accuracy: 0.9813 - val_column_mask_accuracy: 0.9570 - val_loss: 0.0676 - val_table_mask_accuracy: 0.9816
# Epoch 82/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9560 - loss: 0.0503 - table_mask_accuracy: 0.9821
# Epoch 82: val_loss did not improve from 0.06759
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9560 - loss: 0.0503 - table_mask_accuracy: 0.9821 - val_column_mask_accuracy: 0.9559 - val_loss: 0.0722 - val_table_mask_accuracy: 0.9814
# Epoch 83/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - column_mask_accuracy: 0.9572 - loss: 0.0487 - table_mask_accuracy: 0.9823
# Epoch 83: val_loss improved from 0.06759 to 0.06614, saving model to /kaggle/working/checkpoints/mymodel_83.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9572 - loss: 0.0487 - table_mask_accuracy: 0.9823 - val_column_mask_accuracy: 0.9575 - val_loss: 0.0661 - val_table_mask_accuracy: 0.9816
# Epoch 84/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9548 - loss: 0.0729 - table_mask_accuracy: 0.9789
# Epoch 84: val_loss did not improve from 0.06614
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9548 - loss: 0.0730 - table_mask_accuracy: 0.9789 - val_column_mask_accuracy: 0.9455 - val_loss: 0.1933 - val_table_mask_accuracy: 0.9721
# Epoch 85/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9515 - loss: 0.0830 - table_mask_accuracy: 0.9781
# Epoch 85: val_loss did not improve from 0.06614
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9515 - loss: 0.0829 - table_mask_accuracy: 0.9781 - val_column_mask_accuracy: 0.9563 - val_loss: 0.0727 - val_table_mask_accuracy: 0.9815
# Epoch 86/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9534 - loss: 0.0613 - table_mask_accuracy: 0.9800
# Epoch 86: val_loss improved from 0.06614 to 0.06387, saving model to /kaggle/working/checkpoints/mymodel_86.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9534 - loss: 0.0613 - table_mask_accuracy: 0.9800 - val_column_mask_accuracy: 0.9569 - val_loss: 0.0639 - val_table_mask_accuracy: 0.9820
# Epoch 87/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9588 - loss: 0.0462 - table_mask_accuracy: 0.9824
# Epoch 87: val_loss improved from 0.06387 to 0.06268, saving model to /kaggle/working/checkpoints/mymodel_87.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9588 - loss: 0.0462 - table_mask_accuracy: 0.9824 - val_column_mask_accuracy: 0.9577 - val_loss: 0.0627 - val_table_mask_accuracy: 0.9821
# Epoch 88/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9588 - loss: 0.0465 - table_mask_accuracy: 0.9825
# Epoch 88: val_loss improved from 0.06268 to 0.06238, saving model to /kaggle/working/checkpoints/mymodel_88.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9588 - loss: 0.0465 - table_mask_accuracy: 0.9825 - val_column_mask_accuracy: 0.9568 - val_loss: 0.0624 - val_table_mask_accuracy: 0.9820
# Epoch 89/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9572 - loss: 0.0470 - table_mask_accuracy: 0.9822
# Epoch 89: val_loss did not improve from 0.06238
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9572 - loss: 0.0470 - table_mask_accuracy: 0.9822 - val_column_mask_accuracy: 0.9573 - val_loss: 0.0694 - val_table_mask_accuracy: 0.9816
# Epoch 90/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9560 - loss: 0.0462 - table_mask_accuracy: 0.9819
# Epoch 90: val_loss did not improve from 0.06238
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9560 - loss: 0.0462 - table_mask_accuracy: 0.9819 - val_column_mask_accuracy: 0.9568 - val_loss: 0.0700 - val_table_mask_accuracy: 0.9817
# Epoch 91/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9568 - loss: 0.0468 - table_mask_accuracy: 0.9827
# Epoch 91: val_loss did not improve from 0.06238
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9568 - loss: 0.0468 - table_mask_accuracy: 0.9827 - val_column_mask_accuracy: 0.9571 - val_loss: 0.0660 - val_table_mask_accuracy: 0.9823
# Epoch 92/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9573 - loss: 0.0460 - table_mask_accuracy: 0.9821
# Epoch 92: val_loss did not improve from 0.06238
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9573 - loss: 0.0460 - table_mask_accuracy: 0.9821 - val_column_mask_accuracy: 0.8865 - val_loss: 0.3754 - val_table_mask_accuracy: 0.9214
# Epoch 93/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9541 - loss: 0.0683 - table_mask_accuracy: 0.9799
# Epoch 93: val_loss did not improve from 0.06238
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9541 - loss: 0.0682 - table_mask_accuracy: 0.9799 - val_column_mask_accuracy: 0.9562 - val_loss: 0.0771 - val_table_mask_accuracy: 0.9800
# Epoch 94/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9577 - loss: 0.0472 - table_mask_accuracy: 0.9816
# Epoch 94: val_loss improved from 0.06238 to 0.05999, saving model to /kaggle/working/checkpoints/mymodel_94.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9577 - loss: 0.0472 - table_mask_accuracy: 0.9816 - val_column_mask_accuracy: 0.9577 - val_loss: 0.0600 - val_table_mask_accuracy: 0.9821
# Epoch 95/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9574 - loss: 0.0436 - table_mask_accuracy: 0.9822
# Epoch 95: val_loss improved from 0.05999 to 0.05966, saving model to /kaggle/working/checkpoints/mymodel_95.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9574 - loss: 0.0436 - table_mask_accuracy: 0.9822 - val_column_mask_accuracy: 0.9574 - val_loss: 0.0597 - val_table_mask_accuracy: 0.9822
# Epoch 96/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9576 - loss: 0.0452 - table_mask_accuracy: 0.9820
# Epoch 96: val_loss improved from 0.05966 to 0.05661, saving model to /kaggle/working/checkpoints/mymodel_96.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 289ms/step - column_mask_accuracy: 0.9576 - loss: 0.0452 - table_mask_accuracy: 0.9820 - val_column_mask_accuracy: 0.9575 - val_loss: 0.0566 - val_table_mask_accuracy: 0.9827
# Epoch 97/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9584 - loss: 0.0438 - table_mask_accuracy: 0.9821
# Epoch 97: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9584 - loss: 0.0438 - table_mask_accuracy: 0.9821 - val_column_mask_accuracy: 0.9573 - val_loss: 0.0668 - val_table_mask_accuracy: 0.9807
# Epoch 98/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9590 - loss: 0.0447 - table_mask_accuracy: 0.9815
# Epoch 98: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9590 - loss: 0.0447 - table_mask_accuracy: 0.9815 - val_column_mask_accuracy: 0.9567 - val_loss: 0.0589 - val_table_mask_accuracy: 0.9825
# Epoch 99/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9568 - loss: 0.0452 - table_mask_accuracy: 0.9823
# Epoch 99: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9568 - loss: 0.0452 - table_mask_accuracy: 0.9823 - val_column_mask_accuracy: 0.9587 - val_loss: 0.0605 - val_table_mask_accuracy: 0.9822
# Epoch 100/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9568 - loss: 0.0434 - table_mask_accuracy: 0.9821
# Epoch 100: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9568 - loss: 0.0434 - table_mask_accuracy: 0.9821 - val_column_mask_accuracy: 0.9594 - val_loss: 0.0602 - val_table_mask_accuracy: 0.9823
# Epoch 101/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9550 - loss: 0.0471 - table_mask_accuracy: 0.9819
# Epoch 101: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9550 - loss: 0.0471 - table_mask_accuracy: 0.9819 - val_column_mask_accuracy: 0.9565 - val_loss: 0.0591 - val_table_mask_accuracy: 0.9817
# Epoch 102/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9562 - loss: 0.0611 - table_mask_accuracy: 0.9802
# Epoch 102: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9562 - loss: 0.0612 - table_mask_accuracy: 0.9802 - val_column_mask_accuracy: 0.9322 - val_loss: 0.2729 - val_table_mask_accuracy: 0.9583
# Epoch 103/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9470 - loss: 0.1116 - table_mask_accuracy: 0.9730
# Epoch 103: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9470 - loss: 0.1116 - table_mask_accuracy: 0.9730 - val_column_mask_accuracy: 0.9520 - val_loss: 0.0931 - val_table_mask_accuracy: 0.9790
# Epoch 104/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9550 - loss: 0.0634 - table_mask_accuracy: 0.9797
# Epoch 104: val_loss did not improve from 0.05661
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9550 - loss: 0.0634 - table_mask_accuracy: 0.9797 - val_column_mask_accuracy: 0.9566 - val_loss: 0.0627 - val_table_mask_accuracy: 0.9822
# Epoch 105/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9591 - loss: 0.0444 - table_mask_accuracy: 0.9818
# Epoch 105: val_loss improved from 0.05661 to 0.05653, saving model to /kaggle/working/checkpoints/mymodel_105.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9591 - loss: 0.0444 - table_mask_accuracy: 0.9818 - val_column_mask_accuracy: 0.9584 - val_loss: 0.0565 - val_table_mask_accuracy: 0.9829
# Epoch 106/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9587 - loss: 0.0412 - table_mask_accuracy: 0.9823
# Epoch 106: val_loss improved from 0.05653 to 0.05286, saving model to /kaggle/working/checkpoints/mymodel_106.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9587 - loss: 0.0412 - table_mask_accuracy: 0.9823 - val_column_mask_accuracy: 0.9592 - val_loss: 0.0529 - val_table_mask_accuracy: 0.9831
# Epoch 107/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9604 - loss: 0.0379 - table_mask_accuracy: 0.9835
# Epoch 107: val_loss improved from 0.05286 to 0.05135, saving model to /kaggle/working/checkpoints/mymodel_107.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 289ms/step - column_mask_accuracy: 0.9604 - loss: 0.0379 - table_mask_accuracy: 0.9835 - val_column_mask_accuracy: 0.9601 - val_loss: 0.0514 - val_table_mask_accuracy: 0.9833
# Epoch 108/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9604 - loss: 0.0378 - table_mask_accuracy: 0.9826
# Epoch 108: val_loss did not improve from 0.05135
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9604 - loss: 0.0378 - table_mask_accuracy: 0.9826 - val_column_mask_accuracy: 0.9589 - val_loss: 0.0528 - val_table_mask_accuracy: 0.9831
# Epoch 109/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9569 - loss: 0.0396 - table_mask_accuracy: 0.9826
# Epoch 109: val_loss did not improve from 0.05135
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9569 - loss: 0.0396 - table_mask_accuracy: 0.9826 - val_column_mask_accuracy: 0.9597 - val_loss: 0.0542 - val_table_mask_accuracy: 0.9826
# Epoch 110/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9586 - loss: 0.0388 - table_mask_accuracy: 0.9823
# Epoch 110: val_loss improved from 0.05135 to 0.05014, saving model to /kaggle/working/checkpoints/mymodel_110.keras
# ...
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9587 - loss: 0.0333 - table_mask_accuracy: 0.9832 - val_column_mask_accuracy: 0.9577 - val_loss: 0.0554 - val_table_mask_accuracy: 0.9837
# Epoch 162/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9582 - loss: 0.0337 - table_mask_accuracy: 0.9825
# Epoch 162: val_loss did not improve from 0.04508
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 287ms/step - column_mask_accuracy: 0.9582 - loss: 0.0337 - table_mask_accuracy: 0.9825 - val_column_mask_accuracy: 0.9579 - val_loss: 0.0467 - val_table_mask_accuracy: 0.9838
# Epoch 163/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9591 - loss: 0.0330 - table_mask_accuracy: 0.9828
# Epoch 163: val_loss did not improve from 0.04508
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9591 - loss: 0.0330 - table_mask_accuracy: 0.9828 - val_column_mask_accuracy: 0.9592 - val_loss: 0.0510 - val_table_mask_accuracy: 0.9835
# Epoch 164/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9601 - loss: 0.0337 - table_mask_accuracy: 0.9829
# Epoch 164: val_loss improved from 0.04508 to 0.04490, saving model to /kaggle/working/checkpoints/mymodel_164.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9601 - loss: 0.0337 - table_mask_accuracy: 0.9829 - val_column_mask_accuracy: 0.9588 - val_loss: 0.0449 - val_table_mask_accuracy: 0.9834
# Epoch 165/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9585 - loss: 0.0339 - table_mask_accuracy: 0.9820
# Epoch 165: val_loss did not improve from 0.04490
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9585 - loss: 0.0339 - table_mask_accuracy: 0.9820 - val_column_mask_accuracy: 0.9597 - val_loss: 0.0460 - val_table_mask_accuracy: 0.9835
# Epoch 166/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9581 - loss: 0.0489 - table_mask_accuracy: 0.9808
# Epoch 166: val_loss did not improve from 0.04490
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9581 - loss: 0.0489 - table_mask_accuracy: 0.9808 - val_column_mask_accuracy: 0.9563 - val_loss: 0.0720 - val_table_mask_accuracy: 0.9823
# Epoch 167/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9594 - loss: 0.0445 - table_mask_accuracy: 0.9817
# Epoch 167: val_loss did not improve from 0.04490
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9594 - loss: 0.0445 - table_mask_accuracy: 0.9817 - val_column_mask_accuracy: 0.9589 - val_loss: 0.0481 - val_table_mask_accuracy: 0.9835
# Epoch 168/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9574 - loss: 0.0351 - table_mask_accuracy: 0.9822
# Epoch 168: val_loss did not improve from 0.04490
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9574 - loss: 0.0351 - table_mask_accuracy: 0.9822 - val_column_mask_accuracy: 0.9601 - val_loss: 0.0464 - val_table_mask_accuracy: 0.9836
# Epoch 169/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9606 - loss: 0.0328 - table_mask_accuracy: 0.9831
# Epoch 169: val_loss did not improve from 0.04490
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9606 - loss: 0.0328 - table_mask_accuracy: 0.9831 - val_column_mask_accuracy: 0.9299 - val_loss: 0.2500 - val_table_mask_accuracy: 0.9473
# Epoch 170/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9550 - loss: 0.0777 - table_mask_accuracy: 0.9778
# Epoch 170: val_loss did not improve from 0.04490
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9550 - loss: 0.0776 - table_mask_accuracy: 0.9778 - val_column_mask_accuracy: 0.9589 - val_loss: 0.0550 - val_table_mask_accuracy: 0.9829
# Epoch 171/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9601 - loss: 0.0355 - table_mask_accuracy: 0.9829
# Epoch 171: val_loss did not improve from 0.04490
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9601 - loss: 0.0355 - table_mask_accuracy: 0.9829 - val_column_mask_accuracy: 0.9596 - val_loss: 0.0481 - val_table_mask_accuracy: 0.9831
# Epoch 172/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9633 - loss: 0.0308 - table_mask_accuracy: 0.9830
# Epoch 172: val_loss improved from 0.04490 to 0.04477, saving model to /kaggle/working/checkpoints/mymodel_172.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9633 - loss: 0.0308 - table_mask_accuracy: 0.9830 - val_column_mask_accuracy: 0.9602 - val_loss: 0.0448 - val_table_mask_accuracy: 0.9835
# Epoch 173/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9624 - loss: 0.0300 - table_mask_accuracy: 0.9831
# Epoch 173: val_loss improved from 0.04477 to 0.04414, saving model to /kaggle/working/checkpoints/mymodel_173.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9624 - loss: 0.0300 - table_mask_accuracy: 0.9831 - val_column_mask_accuracy: 0.9606 - val_loss: 0.0441 - val_table_mask_accuracy: 0.9837
# Epoch 174/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9621 - loss: 0.0290 - table_mask_accuracy: 0.9839
# Epoch 174: val_loss did not improve from 0.04414
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9621 - loss: 0.0290 - table_mask_accuracy: 0.9839 - val_column_mask_accuracy: 0.9607 - val_loss: 0.0444 - val_table_mask_accuracy: 0.9836
# Epoch 175/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9627 - loss: 0.0296 - table_mask_accuracy: 0.9836
# Epoch 175: val_loss did not improve from 0.04414
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9627 - loss: 0.0296 - table_mask_accuracy: 0.9836 - val_column_mask_accuracy: 0.9606 - val_loss: 0.0443 - val_table_mask_accuracy: 0.9837
# Epoch 176/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9591 - loss: 0.0326 - table_mask_accuracy: 0.9825
# Epoch 176: val_loss did not improve from 0.04414
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9591 - loss: 0.0326 - table_mask_accuracy: 0.9825 - val_column_mask_accuracy: 0.9601 - val_loss: 0.0445 - val_table_mask_accuracy: 0.9835
# Epoch 177/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9601 - loss: 0.0322 - table_mask_accuracy: 0.9833
# Epoch 177: val_loss improved from 0.04414 to 0.04387, saving model to /kaggle/working/checkpoints/mymodel_177.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9601 - loss: 0.0322 - table_mask_accuracy: 0.9833 - val_column_mask_accuracy: 0.9594 - val_loss: 0.0439 - val_table_mask_accuracy: 0.9833
# Epoch 178/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9615 - loss: 0.0317 - table_mask_accuracy: 0.9827
# Epoch 178: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9615 - loss: 0.0317 - table_mask_accuracy: 0.9827 - val_column_mask_accuracy: 0.9604 - val_loss: 0.0456 - val_table_mask_accuracy: 0.9834
# Epoch 179/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9579 - loss: 0.0337 - table_mask_accuracy: 0.9827
# Epoch 179: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9579 - loss: 0.0337 - table_mask_accuracy: 0.9827 - val_column_mask_accuracy: 0.9591 - val_loss: 0.0497 - val_table_mask_accuracy: 0.9826
# Epoch 180/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9600 - loss: 0.0339 - table_mask_accuracy: 0.9831
# Epoch 180: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9600 - loss: 0.0339 - table_mask_accuracy: 0.9831 - val_column_mask_accuracy: 0.9594 - val_loss: 0.0443 - val_table_mask_accuracy: 0.9831
# Epoch 181/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9602 - loss: 0.0327 - table_mask_accuracy: 0.9827
# Epoch 181: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9602 - loss: 0.0327 - table_mask_accuracy: 0.9827 - val_column_mask_accuracy: 0.9587 - val_loss: 0.0454 - val_table_mask_accuracy: 0.9833
# Epoch 182/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9604 - loss: 0.0323 - table_mask_accuracy: 0.9829
# Epoch 182: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9604 - loss: 0.0323 - table_mask_accuracy: 0.9829 - val_column_mask_accuracy: 0.9597 - val_loss: 0.0483 - val_table_mask_accuracy: 0.9829
# Epoch 183/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9577 - loss: 0.0331 - table_mask_accuracy: 0.9826
# Epoch 183: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9577 - loss: 0.0331 - table_mask_accuracy: 0.9826 - val_column_mask_accuracy: 0.9605 - val_loss: 0.0450 - val_table_mask_accuracy: 0.9834
# Epoch 184/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9587 - loss: 0.0385 - table_mask_accuracy: 0.9824
# Epoch 184: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9587 - loss: 0.0385 - table_mask_accuracy: 0.9824 - val_column_mask_accuracy: 0.9553 - val_loss: 0.0701 - val_table_mask_accuracy: 0.9815
# Epoch 185/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9585 - loss: 0.0441 - table_mask_accuracy: 0.9819
# Epoch 185: val_loss did not improve from 0.04387
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9585 - loss: 0.0441 - table_mask_accuracy: 0.9819 - val_column_mask_accuracy: 0.9593 - val_loss: 0.0441 - val_table_mask_accuracy: 0.9834
# Epoch 186/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9588 - loss: 0.0331 - table_mask_accuracy: 0.9828
# Epoch 186: val_loss improved from 0.04387 to 0.04105, saving model to /kaggle/working/checkpoints/mymodel_186.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9588 - loss: 0.0331 - table_mask_accuracy: 0.9828 - val_column_mask_accuracy: 0.9607 - val_loss: 0.0411 - val_table_mask_accuracy: 0.9836
# Epoch 187/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9602 - loss: 0.0303 - table_mask_accuracy: 0.9832
# Epoch 187: val_loss improved from 0.04105 to 0.04067, saving model to /kaggle/working/checkpoints/mymodel_187.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9602 - loss: 0.0303 - table_mask_accuracy: 0.9832 - val_column_mask_accuracy: 0.9598 - val_loss: 0.0407 - val_table_mask_accuracy: 0.9838
# Epoch 188/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9583 - loss: 0.0315 - table_mask_accuracy: 0.9824
# Epoch 188: val_loss improved from 0.04067 to 0.03990, saving model to /kaggle/working/checkpoints/mymodel_188.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 289ms/step - column_mask_accuracy: 0.9583 - loss: 0.0315 - table_mask_accuracy: 0.9824 - val_column_mask_accuracy: 0.9610 - val_loss: 0.0399 - val_table_mask_accuracy: 0.9837
# Epoch 189/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9604 - loss: 0.0304 - table_mask_accuracy: 0.9832
# Epoch 189: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9604 - loss: 0.0304 - table_mask_accuracy: 0.9832 - val_column_mask_accuracy: 0.9591 - val_loss: 0.0412 - val_table_mask_accuracy: 0.9835
# Epoch 190/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9596 - loss: 0.0323 - table_mask_accuracy: 0.9834
# Epoch 190: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9596 - loss: 0.0323 - table_mask_accuracy: 0.9834 - val_column_mask_accuracy: 0.9600 - val_loss: 0.0402 - val_table_mask_accuracy: 0.9836
# Epoch 191/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9623 - loss: 0.0304 - table_mask_accuracy: 0.9838
# Epoch 191: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9623 - loss: 0.0304 - table_mask_accuracy: 0.9838 - val_column_mask_accuracy: 0.9610 - val_loss: 0.0436 - val_table_mask_accuracy: 0.9837
# Epoch 192/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9610 - loss: 0.0304 - table_mask_accuracy: 0.9836
# Epoch 192: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9610 - loss: 0.0304 - table_mask_accuracy: 0.9836 - val_column_mask_accuracy: 0.9617 - val_loss: 0.0435 - val_table_mask_accuracy: 0.9838
# Epoch 193/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9589 - loss: 0.0330 - table_mask_accuracy: 0.9824
# Epoch 193: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9589 - loss: 0.0330 - table_mask_accuracy: 0.9824 - val_column_mask_accuracy: 0.9620 - val_loss: 0.0434 - val_table_mask_accuracy: 0.9836
# Epoch 194/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9609 - loss: 0.0311 - table_mask_accuracy: 0.9830
# Epoch 194: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9609 - loss: 0.0311 - table_mask_accuracy: 0.9830 - val_column_mask_accuracy: 0.9600 - val_loss: 0.0405 - val_table_mask_accuracy: 0.9831
# Epoch 195/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9604 - loss: 0.0320 - table_mask_accuracy: 0.9835
# Epoch 195: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9604 - loss: 0.0320 - table_mask_accuracy: 0.9835 - val_column_mask_accuracy: 0.9602 - val_loss: 0.0453 - val_table_mask_accuracy: 0.9833
# Epoch 196/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9558 - loss: 0.0602 - table_mask_accuracy: 0.9796
# Epoch 196: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9558 - loss: 0.0603 - table_mask_accuracy: 0.9796 - val_column_mask_accuracy: 0.9554 - val_loss: 0.0802 - val_table_mask_accuracy: 0.9807
# Epoch 197/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9538 - loss: 0.0645 - table_mask_accuracy: 0.9788
# Epoch 197: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9538 - loss: 0.0644 - table_mask_accuracy: 0.9788 - val_column_mask_accuracy: 0.9602 - val_loss: 0.0454 - val_table_mask_accuracy: 0.9835
# Epoch 198/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9583 - loss: 0.0356 - table_mask_accuracy: 0.9824
# Epoch 198: val_loss did not improve from 0.03990
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9583 - loss: 0.0356 - table_mask_accuracy: 0.9824 - val_column_mask_accuracy: 0.9606 - val_loss: 0.0405 - val_table_mask_accuracy: 0.9839
# Epoch 199/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9614 - loss: 0.0298 - table_mask_accuracy: 0.9834
# Epoch 199: val_loss improved from 0.03990 to 0.03869, saving model to /kaggle/working/checkpoints/mymodel_199.keras
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 129s 290ms/step - column_mask_accuracy: 0.9614 - loss: 0.0298 - table_mask_accuracy: 0.9834 - val_column_mask_accuracy: 0.9611 - val_loss: 0.0387 - val_table_mask_accuracy: 0.9838
# Epoch 200/200
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - column_mask_accuracy: 0.9620 - loss: 0.0291 - table_mask_accuracy: 0.9830
# Epoch 200: val_loss did not improve from 0.03869
# 444/444 ━━━━━━━━━━━━━━━━━━━━ 128s 288ms/step - column_mask_accuracy: 0.9620 - loss: 0.0291 - table_mask_accuracy: 0.9830 - val_column_mask_accuracy: 0.9587 - val_loss: 0.0480 - val_table_mask_accuracy: 0.9827

# %%
# Load your model
model = load_model(
    '/kaggle/working/checkpoints/mymodel_01.keras',
    custom_objects={
        'table_decoder': table_decoder,
        'column_decoder': column_decoder
    }
)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/layer.py:361: UserWarning: `build()` was called on layer 'table_mask', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/layer.py:361: UserWarning: `build()` was called on layer 'column_mask', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(

# %%
import os
from tensorflow.keras.models import load_model

# Create a directory to save the model if it doesn't exist
layer_save_dir = '/kaggle/working/model_layers'
os.makedirs(layer_save_dir, exist_ok=True)

# Save the entire model using the .keras format, which is efficient and compresses the model
full_model_path = os.path.join(layer_save_dir, 'saved_model.keras')
model.save(full_model_path, save_format='keras')  # This format reduces size and saves both architecture and weights
print(f"Full model saved at: {full_model_path}")

# Alternatively, save the model in the HDF5 format, which is also efficient
full_model_path_h5 = os.path.join(layer_save_dir, 'saved_model.h5')
model.save(full_model_path_h5)
print(f"Full model saved in HDF5 format at: {full_model_path_h5}")
# Out:
# Full model saved at: /kaggle/working/model_layers/saved_model.keras
# Full model saved in HDF5 format at: /kaggle/working/model_layers/saved_model.h5

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(model_history.history['table_mask_accuracy'])
plt.plot(model_history.history['val_table_mask_accuracy'])
plt.title('Model table_mask ')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(model_history.history['column_mask_accuracy'])
plt.plot(model_history.history['val_column_mask_accuracy'])
plt.title('Model column_mask')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(50, 5))
plt.subplot(122)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

def masks(table_mask, column_mask):
  table_mask = tf.argmax(table_mask, axis=-1)
  table_mask = table_mask[..., tf.newaxis]


  column_mask = tf.argmax(column_mask, axis=-1)
  column_mask = column_mask[..., tf.newaxis]
  return table_mask[0], column_mask[0]

# %%
# #checking for table mask
# result(table , predicted_table)

# #checking for column mask
# result(column , predicted_column)

# #randomly comparing predicted output with actual output
# number = 2
# for image, mask  in test_data.take(number):
#   plt.figure(figsize=(30, 50))

#   true_table = mask['table_mask']
#   true_table=tf.keras.preprocessing.image.array_to_img(true_table)
#   true_table = true_table.convert('L')

#   true_column = mask['column_mask']
#   true_column=tf.keras.preprocessing.image.array_to_img(true_column)
#   true_column = true_column.convert('L')


#   mask1, mask2 = model.predict(image[np.newaxis,:,:,:])
#   table_mask, column_mask = masks(mask1, mask2)

#   pred_table = tf.keras.preprocessing.image.array_to_img(table_mask)
#   pred_column = tf.keras.preprocessing.image.array_to_img(column_mask)
#   pred_table = pred_table.convert('L')
#   pred_column = pred_column.convert('L')


#   title = ['Image', 'True Crop', 'Predicted Crop']         
#   for i in range(len(title)): 
#     plt.subplot(1, len(title), i+1)
#     if i == 0:
#       plt.title(title[i],fontsize=15)
#       plt.imshow(tf.keras.preprocessing.image.array_to_img(image))
#       plt.axis('off')

#     elif i == 1:
#       img = tf.keras.preprocessing.image.array_to_img(image)
#       img.putalpha(true_table)
#       #img.putalpha(true_column)
#       plt.title(title[i],fontsize=15)
#       plt.imshow(tf.keras.preprocessing.image.array_to_img(img))
#       plt.axis('off')

#     else:
#       img = tf.keras.preprocessing.image.array_to_img(image)
#       img.putalpha(pred_table)
#       #img.putalpha(pred_column)
#       plt.title(title[i],fontsize=15)
#       plt.imshow(tf.keras.preprocessing.image.array_to_img(img))  
#       plt.axis('off')
#   plt.show()
